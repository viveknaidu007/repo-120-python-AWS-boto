# %%
import boto3

def detect_labels(photo, bucket):

    client=boto3.client('rekognition')

    response = client.detect_labels(Image={'S3Object':{'Bucket':bucket,'Name':photo}},
        MaxLabels=10)

    print('Detected labels for ' + photo) 
    print()   
    for label in response['Labels']:
        print ("Label: " + label['Name'])
        print ("Confidence: " + str(label['Confidence']))
        print ("Instances:")
        for instance in label['Instances']:
            print ("  Bounding box")
            print ("    Top: " + str(instance['BoundingBox']['Top']))
            print ("    Left: " + str(instance['BoundingBox']['Left']))
            print ("    Width: " +  str(instance['BoundingBox']['Width']))
            print ("    Height: " +  str(instance['BoundingBox']['Height']))
            print ("  Confidence: " + str(instance['Confidence']))
            print()

        print ("Parents:")
        for parent in label['Parents']:
            print ("   " + parent['Name'])
        print ("----------")
        print ()
    return len(response['Labels'])


def main():
    photo='weapon2.png'
    bucket='vivekp'
    label_count=detect_labels(photo, bucket)
    print("Labels detected: " + str(label_count))


if __name__ == "__main__":
    main()
# Out:
# Detected labels for weapon2.png
#
# Label: Weapon
# Confidence: 99.90187072753906
# Instances:
# Parents:
# ----------
#
# Label: Bow
# Confidence: 85.82565307617188
# Instances:
# Parents:
#    Weapon
# ----------
#
# Label: Dagger
# Confidence: 84.75335693359375
# Instances:
#   Bounding box
#     Top: 0.2728760242462158
#     Left: 0.11731349676847458
#     Width: 0.8044778108596802
#     Height: 0.49807003140449524
#   Confidence: 84.75335693359375
#
#   Bounding box
#     Top: 0.0
#     Left: 0.000778465298935771
#     Width: 0.762667715549469
#     Height: 0.7909871339797974
#   Confidence: 77.10962677001953
#
# Parents:
#    Blade
#    Knife
#    Weapon
# ----------
#
# Label: Knife
# Confidence: 84.75335693359375
# Instances:
# Parents:
#    Blade
#    Weapon
# ----------
#
# Label: Archery
# Confidence: 64.05223846435547
# Instances:
# Parents:
#    Bow
#    Sport
#    Weapon
# ----------
#
# Label: Sport
# Confidence: 64.05223846435547
# Instances:
# Parents:
# ----------
#
# Label: Spear
# Confidence: 61.506343841552734
# Instances:
# Parents:
#    Weapon
# ----------
#
# Label: Arrow
# Confidence: 57.70647048950195
# Instances:
# Parents:
#    Weapon
# ----------
#
# Label: Archer
# Confidence: 56.44496536254883
# Instances:
# Parents:
#    Archery
#    Bow
#    Person
#    Sport
#    Weapon
# ----------
#
# Label: Arrowhead
# Confidence: 55.05486297607422
# Instances:
# Parents:
#    Arrow
#    Weapon
# ----------
#
# Labels detected: 10

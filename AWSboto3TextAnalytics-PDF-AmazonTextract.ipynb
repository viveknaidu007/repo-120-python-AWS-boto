# %%
import boto3
import time

## Textract APIs used - "start_document_text_detection", "get_document_text_detection"
def InvokeTextDetectJob(s3BucketName, objectName):
    response = None
    client = boto3.client('textract')
    response = client.start_document_text_detection(
            DocumentLocation={
                      'S3Object': {
                                    'Bucket': s3BucketName,
                                    'Name': objectName
                                }
           })
    return response["JobId"]

def CheckJobComplete(jobId):
    time.sleep(5)
    client = boto3.client('textract')
    response = client.get_document_text_detection(JobId=jobId)
    status = response["JobStatus"]
    print("Job status: {}".format(status))
    while(status == "IN_PROGRESS"):
        time.sleep(5)
        response = client.get_document_text_detection(JobId=jobId)
        status = response["JobStatus"]
        print("Job status: {}".format(status))
    return status

def JobResults(jobId):
    pages = []
    client = boto3.client('textract')
    response = client.get_document_text_detection(JobId=jobId)
 
    pages.append(response)
    print("Resultset page recieved: {}".format(len(pages)))
    nextToken = None
    if('NextToken' in response):
        nextToken = response['NextToken']
        while(nextToken):
            response = client.get_document_text_detection(JobId=jobId, NextToken=nextToken)
            pages.append(response)
            print("Resultset page recieved: {}".format(len(pages)))
            nextToken = None
            if('NextToken' in response):
                nextToken = response['NextToken']
    return pages

# S3 Document Data
s3BucketName = "vivekp"
documentName = "12.Lists.pdf"

# Function invokes
jobId = InvokeTextDetectJob(s3BucketName, documentName)
print("Started job with id: {}".format(jobId))
if(CheckJobComplete(jobId)):
    response = JobResults(jobId)
    for resultPage in response:
        for item in resultPage["Blocks"]:
            if item["BlockType"] == "LINE":
                print ('\033[94m' + item["Text"] + '\033[0m')
# Out:
# Started job with id: d4e6da6fca63702ddd1adec87c3bfd655f279fcd5c1e1cf98275d2fc9068dad1
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Lists
# Defnition
# A list is a versatile and mutable data structure
# used to store a collection of items.
# Defined using square brackets []
# Contain elements of different data types
# Allow duplicates.
# 01
# Creating
# 02
# Indexing
# Python
# 03
# Slicing
# Lists
# 04
# Modifying
# Tech
# Creating Lists
# you enclose the elements inside square brackets,
# separated by commas.
# empty, list = []
# numbers = [1, 2, 3, 4, 5]
# fruits = ["apple", "banana", "cherry"]
# mixed_ list = [1, "hello", 3.14, True]
# Accessing Elements
# You can access individual elements of a list using
# their index. Indexing in Python starts from O.
# fruits = ["apple", "banana", "cherry"]
# print (fruits[0]) # Output: "apple"
# print (fruits[1]) Output: "banana"
# Python also supports negative indexing, where -1
# refers to the last element
# Slicing Lists
# You can extract a portion of a list using slicing. Slicing
# allows you to create a new list with a subset of elements.
# numbers = [1, 2, 3, 4, 5]
# print (numbers[1:4])
# #
# Output: [2, 3, 4]
# Modifying Elements
# You can modify individual elements in a list by accessing
# them using their index and then assigning a new value.
# fruits = ["apple", "banana", "cherry"]
# fruits[0] = "orange"
# print(fruits)
# Output: ["orange", "banana", "cherry"]
# </>
# db
# ()1105
# ()dod
# ()tunos
# </>
# ()xapu!
# ()puedde
# append(): Adds an element to the end of the
# list.
# insert(): Inserts an element at a specific index.
# remove(): Removes the first occurrence of a
# specified element.
# pop(): Removes and returns the element at a
# specified index (or the last element if no index
# is given).
# index(): Returns the index of the first
# occurrence of a specified element.
# count(): Returns the number of occurrences of
# a specified element in the list.
# sort(): Sorts the list in ascending order.
# reverse (): Reverses the order of the elements in
# the list.
# Python List Methods
# Input
# Method
# Output
# .append
# (
# )
# insert( (1,
# pop ( 1)
# .remove
# (
# )
# .reverse
# ()
# .sort
# ()
# .index
# (
# )
# 2
# .count
# (
# )
# 2
# List Concatenation
# Lists can be concatenated using the + operator, which
# creates a new list containing elements from both lists.
# list1 = [1, 2, 3]
# list2 = [4, 5, 6]
# combined list = list1 + list2
# print (combined_list) Output: [1, 2, 3, 4, 5, 6]
# List Comprehensions
# List comprehensions provide a concise way to create lists
# using a single line of code.
# Syntax
# new_list = [expression for item in iterable if condition]
# squares = [x**2 for X in range (1, 6)]
# print (squares)
# Output: [1, 4, 9, 16, 25]

# %%
import boto3
import time

## Textract APIs used - "start_document_text_detection", "get_document_text_detection"
def InvokeTextDetectJob(s3BucketName, objectName):
    response = None
    client = boto3.client('textract')
    response = client.start_document_text_detection(
            DocumentLocation={
                      'S3Object': {
                                    'Bucket': s3BucketName,
                                    'Name': objectName
                                }
           })
    return response["JobId"]

def CheckJobComplete(jobId):
    time.sleep(5)
    client = boto3.client('textract')
    response = client.get_document_text_detection(JobId=jobId)
    status = response["JobStatus"]
    print("Job status: {}".format(status))
    while(status == "IN_PROGRESS"):
        time.sleep(5)
        response = client.get_document_text_detection(JobId=jobId)
        status = response["JobStatus"]
        print("Job status: {}".format(status))
    return status

def JobResults(jobId):
    pages = []
    client = boto3.client('textract')
    response = client.get_document_text_detection(JobId=jobId)
 
    pages.append(response)
    print("Resultset page recieved: {}".format(len(pages)))
    nextToken = None
    if('NextToken' in response):
        nextToken = response['NextToken']
        while(nextToken):
            response = client.get_document_text_detection(JobId=jobId, NextToken=nextToken)
            pages.append(response)
            print("Resultset page recieved: {}".format(len(pages)))
            nextToken = None
            if('NextToken' in response):
                nextToken = response['NextToken']
    return pages

# S3 Document Data
s3BucketName = "vivekp"
documentName = "spokenenglish_report_2016-17.pdf"

# Function invokes
jobId = InvokeTextDetectJob(s3BucketName, documentName)
print("Started job with id: {}".format(jobId))
if(CheckJobComplete(jobId)):
    response = JobResults(jobId)
    for resultPage in response:
        for item in resultPage["Blocks"]:
            if item["BlockType"] == "LINE":
                print ('\033[94m' + item["Text"] + '\033[0m')
# Out:
# Started job with id: 62f0796a6bcdadc631d83ed75b2c1a6f0a0fabdcf8f11a571c90b5808e73a365
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Spoken English Course (48 hours)
# (16-01-2017)
# Course Syllabus/Curriculum:
# 1. Week One: - Story/video Based Activities
# 1) The task is to go to the nearest vegetable market and write down the names of
# at least 15vegetables both in Hindi and English.
# Or,
# Write down the recipe of any cuisine that you know properly in 100-150 words.
# 2) A video will be shown to students in a short while. Before that, read what the
# video is allabout in Hindi:
# 3) Pronunciation of different words
# 4) Students will be given a video listing the common words wrongly pronounced.
# Students watch the video. Students listen the pronunciation properly and practice
# them.
# 2. Week Two- Group Interaction and Personal Interview
# 3. Week Three - Grammar
# What is tense and their explanations
# Fill in the blanks with appropriate tense form of the verb.
# How to Change the verb into the correct form.
# Active/Passive Voice exercise
# How and when do we use each of the English modal verbs?
# 4. Week Four - Personality Development, Ethical Behaviour
# 5. Week Five - Reading Skills
# Reading News headlines
# The students would read the running headlines on the screen/prompter.
# The students will be asked to recite the poems.
# They should be taught the power of vocabulary, importance of word placing,
# appropriateexpressions while reading/reciting and SO on.
# The groups should be formed and within their groups each student would recite
# the poemamong group members. Their anxiety level to be checked.
# 6.
# Week Six - Writing skill
# Story writing, Letter writing, Notice writing, E-Mail writing, Note Making, Essay
# writing.
# Assessment Procedure:
# The students will narrate a story or review any film that they like. The students have to inform
# the teacher of their chosen story/film in the previous class itself. The students will be asked to
# pronounce words properly. Mock interviews, Practice Session and the tutorial are conducted.
# Assessment/ learning progress including achievements in interaction at various levels and
# Assessment through surprise activities.
# Summary Report
# The Department of English, under the guidance of the Principal Prof. Rabi Narayan Kar, came
# up with an idea of a Spoken English Course for the students of the College from 16th January,
# 2017 for academic session 2016-17. The course was meant for those students who faced
# difficulties and were unable to acquire English language skills properly. Thereupon, through
# collective efforts of the Department and valuable inputs from the Principal, a module was
# drafted. Initially, the basic structure of the Module was prepared keeping in view the NPTEL
# Spoken English course module. However, the Department felt that since the course is meant
# for the beginners, it would be better to arrange the content module according to the
# requirements of the SLC students.
# In its final package, the course was designed as a Six-Week Spoken English Course (four days
# per week) and though primary focus was on spoken English, it also included reading and
# writing sections other than speaking and listening.
# The response from the students was overwhelming; total 50 students were shortlisted for the
# course. In its introductory session the Seminar Hall was jam-packed and students
# enthusiastically wanted to be the part of it. Prof. Kar, the principal, addressed the students
# intimating them about the importance of English in social and corporate realms. He also
# appreciated the effort of English Department and congratulated Dr. Kusha Tiwari, TIC,
# English Department, who was the guiding force behind the entire module.
# Witnessing such a huge response from the students, Prof. Kar had to announce that at its
# growing stage the Course would not be able to accommodate SO many students and requested
# the Department of English to run the course both in odd and even semesters.
# The Course weeks were divided among five teachers which wereas follows:
# 1)Mr. Anuj Kushwaha (Week 1)
# 2) Dr. Mukuta Borah (Week 2)
# 3)Mr. Abbasuddin Tapadar (Week 3)
# 4)Mr. Rajarshi Kalita (Week 4)
# 5)Ms. Alphinah (Week 5)
# 6)Mr. Anuj Kushwaha (Week 6)
# The sessions were interactive, informative and interesting. The usage of videos, hand-outs,
# stories, comics, suggestive books and interesting worksheets helped the students to grasp the
# tips to learn and understand English language. There were brain-storming sessions, debates,
# group activities and impromptu presentations which enhanced the confidence level of the
# students.
# In Week One, Mr. Anuj Kushwaha started the session on a lighter note with the help of
# YouTube videos. The objective was to help the students to utilise the opportunities close at
# hand to learn English. Social media platforms viz. Facebook, YouTube, Instagram etc. provide
# learners with a space to learn, interact, participate and grow.
# In this regard, a YouTube tutorial video on food recipe was shown to the students. The
# language in the video was Hindi with English subtitles. The students were able to learn
# culinary/cuisine specific vocabulary and articulate their own sentences both in Hindi and
# English using the vocabulary (Belan: rolling pin, Channi/Chalani: sieve and SO on) from the
# video. The students found the method interesting.
# In Week Two, Dr. Mukuta Borah taught grammar to the students beginning with tenses and
# helped them in framing simple sentences in English. The students were also engaged in
# conversations based on simple present tense. A doubt clearing session was also organised at
# the end of the week.
# In Week Three, Mr. Abbas Tapadar worked on the pronunciation of the students and delivered
# elementary yet essential tips of transcription which could enhance the speaking style of the
# students.
# In Week Four, Mr. Rajarshi Kalita interacted with the students and gave valuable inputs on
# communication skills- verbal and non-verbal. The students cherished his discussions on
# 'expressing silence' and how to say 'no'. The students made remarkable improvement at that
# juncture.
# In Week Five, Ms. Alpinah focussed on the writing skills of the students. They were given tips
# to write/draft formal/official letters, reports, e-mails, CV/resume etc which would help them at
# professional level.
# In Week Six, based on the experiences gained by the students in five weeks Mr. Anuj
# organised some more activity based interactive sessions. The students were given graphic
# stories (Indian) with hidden captions and were urged to interpret the conversations on their
# own.
# A group based activity was also arranged wherein the students were given a situation and they
# were asked to initiate conversation as they deemed fit. The Course ran its entire course of
# weeks and also took informal inputs from the students for making the course better next time.
# Total duration of this course was 48 hrs.
# Learning Outcomes:
# The students should be able to:
# 1) Articulate basic English words with ease and communicate with confidence
# 2) Pronounce the words correctly and able to identify the usage of words according to occasion
# (register).
# 3) Read, write and speak Basic English at professional/formal places.
# 4) Apply verbal and non-verbal techniques to experience enhanced expression quality during
# speaking.
# 5) Feel encouraged moving to advanced level of speaking, writing and reading skills.
